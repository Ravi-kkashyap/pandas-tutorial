# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name" : ['Ram','Rohan','Kirti','Himanshi','Chahat','Charan','Akash'],
    "City" : ['Bnagalore','Jaipur','Delhi','Gurgaon','Ambala','Lucknow','Hyderabad'],
    "Marks" : [85,60,78,54,89,91,45]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        Name       City  Marks
# 0       Ram  Bnagalore     85
# 1     Rohan     Jaipur     60
# 2     Kirti      Delhi     78
# 3  Himanshi    Gurgaon     54
# 4    Chahat     Ambala     89
# 5    Charan    Lucknow     91
# 6     Akash  Hyderabad     45

# %%
df.to_csv('Results.csv')

# %%
df.to_csv('marks.csv',index=False)

# %%
df.head(2)
# Out:
#     Name       City  Marks
# 0    Ram  Bnagalore     85
# 1  Rohan     Jaipur     60

# %%
df.tail(3)
# Out:
#      Name       City  Marks
# 4  Chahat     Ambala     89
# 5  Charan    Lucknow     91
# 6   Akash  Hyderabad     45

# %%
df.head()
# Out:
#        Name       City  Marks
# 0       Ram  Bnagalore     85
# 1     Rohan     Jaipur     60
# 2     Kirti      Delhi     78
# 3  Himanshi    Gurgaon     54
# 4    Chahat     Ambala     89

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   71.714286
# std    18.490667
# min    45.000000
# 25%    57.000000
# 50%    78.000000
# 75%    87.000000
# max    91.000000

# %%
df1=pd.read_csv('marks.csv')

# %%
df1
# Out:
#        Name       City  Marks
# 0       Ram  Bnagalore     85
# 1     Rohan     Jaipur     60
# 2     Kirti      Delhi     78
# 3  Himanshi    Gurgaon     54
# 4    Chahat     Ambala     89
# 5    Charan    Lucknow     91
# 6     Akash  Hyderabad     45

# %%
df['City']
# Out:
# 0    Bnagalore
# 1       Jaipur
# 2        Delhi
# 3      Gurgaon
# 4       Ambala
# 5      Lucknow
# 6    Hyderabad
# Name: City, dtype: object

# %%
df['City'][4]
# Out:
# 'Ambala'

# %%
df['Marks'][6]=68
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#        Name       City  Marks
# 0       Ram  Bnagalore     85
# 1     Rohan     Jaipur     60
# 2     Kirti      Delhi     78
# 3  Himanshi    Gurgaon     54
# 4    Chahat     Ambala     89
# 5    Charan    Lucknow     91
# 6     Akash  Hyderabad     68

# %%
df.to_csv('Score.csv',index = False)

# %%
df.index = ['one','two','three','four','five','six','seven']

# %%
df
# Out:
#            Name       City  Marks
# one         Ram  Bnagalore     85
# two       Rohan     Jaipur     60
# three     Kirti      Delhi     78
# four   Himanshi    Gurgaon     54
# five     Chahat     Ambala     89
# six      Charan    Lucknow     91
# seven     Akash  Hyderabad     68

# %%
ser = pd.Series(np.random.rand)

# %%
ser = pd.Series(np.random.rand(10))

# %%
ser
# Out:
# 0    0.998475
# 1    0.450701
# 2    0.485746
# 3    0.042924
# 4    0.445381
# 5    0.814538
# 6    0.720791
# 7    0.432248
# 8    0.974650
# 9    0.644171
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(300,5) , index = np.arange(300))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.231825  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.231825  0.010970  0.596557  0.192882  0.749847
# 1  0.077450  0.040576  0.312042  0.707365  0.438977
# 2  0.859361  0.277885  0.594019  0.428499  0.359321
# 3  0.228923  0.765488  0.347889  0.752971  0.576856
# 4  0.866311  0.151492  0.499286  0.867768  0.977410

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.524464    0.487621    0.536306    0.539271    0.494946
# std      0.291725    0.285403    0.287069    0.284170    0.292414
# min      0.001909    0.001334    0.000420    0.005249    0.001838
# 25%      0.280771    0.234300    0.301234    0.289203    0.249162
# 50%      0.508122    0.496236    0.547097    0.571380    0.480514
# 75%      0.786889    0.723593    0.786443    0.789833    0.745522
# max      0.999422    0.999826    0.998217    0.995925    0.999618

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.231825  0.010970  0.596557  0.192882  0.749847
# 1  0.077450  0.040576  0.312042  0.707365  0.438977
# 2  0.859361  0.277885  0.594019  0.428499  0.359321
# 3  0.228923  0.765488  0.347889  0.752971  0.576856
# 4  0.866311  0.151492  0.499286  0.867768  0.977410

# %%
df.columns
# Out:
# Index(['Name', 'City', 'Marks'], dtype='object')

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf.to_numpy()
# Out:
# array([[0.23182509, 0.01096977, 0.59655657, 0.19288235, 0.74984737],
#        [0.07744988, 0.0405757 , 0.31204204, 0.70736548, 0.43897653],
#        [0.85936053, 0.27788476, 0.59401901, 0.42849883, 0.35932131],
#        ...,
#        [0.30052446, 0.69146989, 0.07271493, 0.89515129, 0.36473478],
#        [0.19724793, 0.54539431, 0.94806639, 0.20846582, 0.68765198],
#        [0.64167808, 0.96631565, 0.89252847, 0.55653069, 0.57926579]])

# %%
df.to_numpy()
# Out:
# array([['Ram', 'Bnagalore', 85],
#        ['Rohan', 'Jaipur', 60],
#        ['Kirti', 'Delhi', 78],
#        ['Himanshi', 'Gurgaon', 54],
#        ['Chahat', 'Ambala', 89],
#        ['Charan', 'Lucknow', 91],
#        ['Akash', 'Hyderabad', 68]], dtype=object)

# %%
newdf.T
# Out:
#         0         1         2    ...       297       298       299
# 0  0.231825  0.077450  0.859361  ...  0.300524  0.197248  0.641678
# 1  0.010970  0.040576  0.277885  ...  0.691470  0.545394  0.966316
# 2  0.596557  0.312042  0.594019  ...  0.072715  0.948066  0.892528
# 3  0.192882  0.707365  0.428499  ...  0.895151  0.208466  0.556531
# 4  0.749847  0.438977  0.359321  ...  0.364735  0.687652  0.579266
#
# [5 rows x 300 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.231825  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.sort_index(axis = 0, ascending = False)
# Out:
#             0         1         2         3         4
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# ..        ...       ...       ...       ...       ...
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 0    0.231825  0.010970  0.596557  0.192882  0.749847
#
# [300 rows x 5 columns]

# %%
newdf.sort_index(axis = 0)
# Out:
#             0         1         2         3         4
# 0    0.231825  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
 newdf[0]
# Out:
# 0      0.231825
# 1      0.077450
# 2      0.859361
# 3      0.228923
# 4      0.866311
#          ...
# 295    0.483345
# 296    0.546662
# 297    0.300524
# 298    0.197248
# 299    0.641678
# Name: 0, Length: 300, dtype: float64

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
df['City']
# Out:
# one      Bnagalore
# two         Jaipur
# three        Delhi
# four       Gurgaon
# five        Ambala
# six        Lucknow
# seven    Hyderabad
# Name: City, dtype: object

# %%
type(df['City'])
# Out:
# pandas.core.series.Series

# %%
newdf2 = newdf.copy()

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0    0.231825  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf2 = newdf

# %%
newdf2[0][0] = 567

# %%
newdf2
# Out:
#               0         1         2         3         4
# 0    567.000000  0.010970  0.596557  0.192882  0.749847
# 1      0.077450  0.040576  0.312042  0.707365  0.438977
# 2      0.859361  0.277885  0.594019  0.428499  0.359321
# 3      0.228923  0.765488  0.347889  0.752971  0.576856
# 4      0.866311  0.151492  0.499286  0.867768  0.977410
# ..          ...       ...       ...       ...       ...
# 295    0.483345  0.803945  0.131505  0.610142  0.279954
# 296    0.546662  0.757105  0.347029  0.978767  0.908310
# 297    0.300524  0.691470  0.072715  0.895151  0.364735
# 298    0.197248  0.545394  0.948066  0.208466  0.687652
# 299    0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf
# Out:
#               0         1         2         3         4
# 0    567.000000  0.010970  0.596557  0.192882  0.749847
# 1      0.077450  0.040576  0.312042  0.707365  0.438977
# 2      0.859361  0.277885  0.594019  0.428499  0.359321
# 3      0.228923  0.765488  0.347889  0.752971  0.576856
# 4      0.866311  0.151492  0.499286  0.867768  0.977410
# ..          ...       ...       ...       ...       ...
# 295    0.483345  0.803945  0.131505  0.610142  0.279954
# 296    0.546662  0.757105  0.347029  0.978767  0.908310
# 297    0.300524  0.691470  0.072715  0.895151  0.364735
# 298    0.197248  0.545394  0.948066  0.208466  0.687652
# 299    0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf[0][0] = 0.828766

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.828766  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf2 = newdf.copy()

# %%
newdf2[1][1]
# Out:
# 0.040575704933809575

# %%
newdf2[1][1] = 56733

# %%
newdf2
# Out:
#             0             1         2         3         4
# 0    0.828766      0.010970  0.596557  0.192882  0.749847
# 1    0.077450  56733.000000  0.312042  0.707365  0.438977
# 2    0.859361      0.277885  0.594019  0.428499  0.359321
# 3    0.228923      0.765488  0.347889  0.752971  0.576856
# 4    0.866311      0.151492  0.499286  0.867768  0.977410
# ..        ...           ...       ...       ...       ...
# 295  0.483345      0.803945  0.131505  0.610142  0.279954
# 296  0.546662      0.757105  0.347029  0.978767  0.908310
# 297  0.300524      0.691470  0.072715  0.895151  0.364735
# 298  0.197248      0.545394  0.948066  0.208466  0.687652
# 299  0.641678      0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.828766  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0    0.828766  0.010970  0.596557  0.192882  0.749847
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 2    0.859361  0.277885  0.594019  0.428499  0.359321
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 4    0.866311  0.151492  0.499286  0.867768  0.977410
# ..        ...       ...       ...       ...       ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954
# 296  0.546662  0.757105  0.347029  0.978767  0.908310
# 297  0.300524  0.691470  0.072715  0.895151  0.364735
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
# 299  0.641678  0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E
# 0  0.828766  0.010970  0.596557  0.192882  0.749847
# 1  0.077450  0.040576  0.312042  0.707365  0.438977
# 2  0.859361  0.277885  0.594019  0.428499  0.359321

# %%
newdf.loc[0,0] = 123

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0    0.828766  0.010970  0.596557  0.192882  0.749847  123.0
# 1    0.077450  0.040576  0.312042  0.707365  0.438977    NaN
# 2    0.859361  0.277885  0.594019  0.428499  0.359321    NaN
# 3    0.228923  0.765488  0.347889  0.752971  0.576856    NaN
# 4    0.866311  0.151492  0.499286  0.867768  0.977410    NaN
# ..        ...       ...       ...       ...       ...    ...
# 295  0.483345  0.803945  0.131505  0.610142  0.279954    NaN
# 296  0.546662  0.757105  0.347029  0.978767  0.908310    NaN
# 297  0.300524  0.691470  0.072715  0.895151  0.364735    NaN
# 298  0.197248  0.545394  0.948066  0.208466  0.687652    NaN
# 299  0.641678  0.966316  0.892528  0.556531  0.579266    NaN
#
# [300 rows x 6 columns]

# %%
newdf.loc[2,'B']=8954.455

# %%
newdf
# Out:
#             A            B         C         D         E      0
# 0    0.828766     0.010970  0.596557  0.192882  0.749847  123.0
# 1    0.077450     0.040576  0.312042  0.707365  0.438977    NaN
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321    NaN
# 3    0.228923     0.765488  0.347889  0.752971  0.576856    NaN
# 4    0.866311     0.151492  0.499286  0.867768  0.977410    NaN
# ..        ...          ...       ...       ...       ...    ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954    NaN
# 296  0.546662     0.757105  0.347029  0.978767  0.908310    NaN
# 297  0.300524     0.691470  0.072715  0.895151  0.364735    NaN
# 298  0.197248     0.545394  0.948066  0.208466  0.687652    NaN
# 299  0.641678     0.966316  0.892528  0.556531  0.579266    NaN
#
# [300 rows x 6 columns]

# %%
newdf.head(3)
# Out:
#           A            B         C         D         E      0
# 0  0.828766     0.010970  0.596557  0.192882  0.749847  123.0
# 1  0.077450     0.040576  0.312042  0.707365  0.438977    NaN
# 2  0.859361  8954.455000  0.594019  0.428499  0.359321    NaN

# %%
newdf = newdf.drop(0,axis = 1)

# %%
newdf
# Out:
#             A            B         C         D         E
# 0    0.828766     0.010970  0.596557  0.192882  0.749847
# 1    0.077450     0.040576  0.312042  0.707365  0.438977
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321
# 3    0.228923     0.765488  0.347889  0.752971  0.576856
# 4    0.866311     0.151492  0.499286  0.867768  0.977410
# ..        ...          ...       ...       ...       ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954
# 296  0.546662     0.757105  0.347029  0.978767  0.908310
# 297  0.300524     0.691470  0.072715  0.895151  0.364735
# 298  0.197248     0.545394  0.948066  0.208466  0.687652
# 299  0.641678     0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.312042  0.707365
# 2  0.594019  0.428499

# %%
newdf.loc[:,['A','B']]
# Out:
#             A            B
# 0    0.828766     0.010970
# 1    0.077450     0.040576
# 2    0.859361  8954.455000
# 3    0.228923     0.765488
# 4    0.866311     0.151492
# ..        ...          ...
# 295  0.483345     0.803945
# 296  0.546662     0.757105
# 297  0.300524     0.691470
# 298  0.197248     0.545394
# 299  0.641678     0.966316
#
# [300 rows x 2 columns]

# %%
newdf.loc[[3,4],:]
# Out:
#           A         B         C         D         E
# 3  0.228923  0.765488  0.347889  0.752971  0.576856
# 4  0.866311  0.151492  0.499286  0.867768  0.977410

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 1    0.077450  0.040576  0.312042  0.707365  0.438977
# 3    0.228923  0.765488  0.347889  0.752971  0.576856
# 8    0.195647  0.613836  0.649697  0.312460  0.739920
# 17   0.020740  0.966898  0.419182  0.878236  0.030028
# 18   0.199279  0.482664  0.285435  0.530214  0.966889
# ..        ...       ...       ...       ...       ...
# 285  0.084283  0.947462  0.240552  0.581980  0.920971
# 290  0.056382  0.722999  0.308364  0.831049  0.908347
# 292  0.177676  0.745402  0.553026  0.574704  0.468603
# 294  0.248315  0.069217  0.189775  0.731600  0.873810
# 298  0.197248  0.545394  0.948066  0.208466  0.687652
#
# [78 rows x 5 columns]

# %%
newdf.loc[(newdf['B']>0.4) & (newdf['E']<0.2)]
# Out:
#             A         B         C         D         E
# 12   0.472996  0.943913  0.841059  0.486131  0.189874
# 17   0.020740  0.966898  0.419182  0.878236  0.030028
# 22   0.401429  0.772293  0.144502  0.988164  0.083001
# 32   0.072703  0.796648  0.744570  0.017207  0.120613
# 39   0.394247  0.459280  0.982879  0.483675  0.032400
# 42   0.401144  0.556040  0.077860  0.346182  0.004360
# 56   0.718917  0.974244  0.318543  0.571797  0.046361
# 86   0.889460  0.712769  0.386397  0.830958  0.089061
# 98   0.778327  0.700927  0.226084  0.130479  0.011493
# 108  0.097757  0.415452  0.997257  0.596376  0.003404
# 117  0.208992  0.531907  0.539599  0.649587  0.064451
# 118  0.710854  0.931500  0.981748  0.404762  0.159105
# 120  0.421275  0.513578  0.683317  0.433852  0.001838
# 125  0.081038  0.534801  0.984941  0.617613  0.160640
# 133  0.843407  0.775713  0.254122  0.762138  0.040799
# 134  0.304337  0.765538  0.973975  0.586124  0.186156
# ...

# %%
newdf.loc[(newdf['C']>1)]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
newdf
# Out:
#             A            B         C         D         E
# 0    0.828766     0.010970  0.596557  0.192882  0.749847
# 1    0.077450     0.040576  0.312042  0.707365  0.438977
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321
# 3    0.228923     0.765488  0.347889  0.752971  0.576856
# 4    0.866311     0.151492  0.499286  0.867768  0.977410
# ..        ...          ...       ...       ...       ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954
# 296  0.546662     0.757105  0.347029  0.978767  0.908310
# 297  0.300524     0.691470  0.072715  0.895151  0.364735
# 298  0.197248     0.545394  0.948066  0.208466  0.687652
# 299  0.641678     0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.iloc[0,1]
# Out:
# 0.010969770133245849

# %%
df.iloc[0,2]
# Out:
# 85

# %%
newdf.iloc[[2,3],[3,4]]
# Out:
#           D         E
# 2  0.428499  0.359321
# 3  0.752971  0.576856

# %%
newdf.loc[1,'A']
# Out:
# 0.0774498818863868

# %%
newdf
# Out:
#             A            B         C         D         E
# 0    0.828766     0.010970  0.596557  0.192882  0.749847
# 1    0.077450     0.040576  0.312042  0.707365  0.438977
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321
# 3    0.228923     0.765488  0.347889  0.752971  0.576856
# 4    0.866311     0.151492  0.499286  0.867768  0.977410
# ..        ...          ...       ...       ...       ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954
# 296  0.546662     0.757105  0.347029  0.978767  0.908310
# 297  0.300524     0.691470  0.072715  0.895151  0.364735
# 298  0.197248     0.545394  0.948066  0.208466  0.687652
# 299  0.641678     0.966316  0.892528  0.556531  0.579266
#
# [300 rows x 5 columns]

# %%
newdf.drop([0,5])
# Out:
#             A            B         C         D         E
# 1    0.077450     0.040576  0.312042  0.707365  0.438977
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321
# 3    0.228923     0.765488  0.347889  0.752971  0.576856
# 4    0.866311     0.151492  0.499286  0.867768  0.977410
# 6    0.498429     0.934376  0.521447  0.597612  0.510244
# ..        ...          ...       ...       ...       ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954
# 296  0.546662     0.757105  0.347029  0.978767  0.908310
# 297  0.300524     0.691470  0.072715  0.895151  0.364735
# 298  0.197248     0.545394  0.948066  0.208466  0.687652
# 299  0.641678     0.966316  0.892528  0.556531  0.579266
#
# [298 rows x 5 columns]

# %%
newdf.drop(['A','D'],axis=1)
# Out:
#                B         C         E
# 0       0.010970  0.596557  0.749847
# 1       0.040576  0.312042  0.438977
# 2    8954.455000  0.594019  0.359321
# 3       0.765488  0.347889  0.576856
# 4       0.151492  0.499286  0.977410
# ..           ...       ...       ...
# 295     0.803945  0.131505  0.279954
# 296     0.757105  0.347029  0.908310
# 297     0.691470  0.072715  0.364735
# 298     0.545394  0.948066  0.687652
# 299     0.966316  0.892528  0.579266
#
# [300 rows x 3 columns]

# %%
newdf
# Out:
#             A            B         C         D         E
# 1    0.077450     0.040576  0.312042  0.707365  0.438977
# 2    0.859361  8954.455000  0.594019  0.428499  0.359321
# 3    0.228923     0.765488  0.347889  0.752971  0.576856
# 5    0.505043     0.481383  0.247779  0.288078  0.745009
# 6    0.498429     0.934376  0.521447  0.597612  0.510244
# ..        ...          ...       ...       ...       ...
# 295  0.483345     0.803945  0.131505  0.610142  0.279954
# 296  0.546662     0.757105  0.347029  0.978767  0.908310
# 297  0.300524     0.691470  0.072715  0.895151  0.364735
# 298  0.197248     0.545394  0.948066  0.208466  0.687652
# 299  0.641678     0.966316  0.892528  0.556531  0.579266
#
# [298 rows x 5 columns]

# %%
newdf=newdf.drop(['A','D'],axis = 1)

# %%
newdf
# Out:
#                B         C         E
# 1       0.040576  0.312042  0.438977
# 2    8954.455000  0.594019  0.359321
# 3       0.765488  0.347889  0.576856
# 5       0.481383  0.247779  0.745009
# 6       0.934376  0.521447  0.510244
# ..           ...       ...       ...
# 295     0.803945  0.131505  0.279954
# 296     0.757105  0.347029  0.908310
# 297     0.691470  0.072715  0.364735
# 298     0.545394  0.948066  0.687652
# 299     0.966316  0.892528  0.579266
#
# [298 rows x 3 columns]

# %%
newdf.reset_index()
# Out:
#      index            B         C         E
# 0        1     0.040576  0.312042  0.438977
# 1        2  8954.455000  0.594019  0.359321
# 2        3     0.765488  0.347889  0.576856
# 3        5     0.481383  0.247779  0.745009
# 4        6     0.934376  0.521447  0.510244
# ..     ...          ...       ...       ...
# 293    295     0.803945  0.131505  0.279954
# 294    296     0.757105  0.347029  0.908310
# 295    297     0.691470  0.072715  0.364735
# 296    298     0.545394  0.948066  0.687652
# 297    299     0.966316  0.892528  0.579266
#
# [298 rows x 4 columns]

# %%
newdf.reset_index(drop = True)
# Out:
#                B         C         E
# 0       0.040576  0.312042  0.438977
# 1    8954.455000  0.594019  0.359321
# 2       0.765488  0.347889  0.576856
# 3       0.481383  0.247779  0.745009
# 4       0.934376  0.521447  0.510244
# ..           ...       ...       ...
# 293     0.803945  0.131505  0.279954
# 294     0.757105  0.347029  0.908310
# 295     0.691470  0.072715  0.364735
# 296     0.545394  0.948066  0.687652
# 297     0.966316  0.892528  0.579266
#
# [298 rows x 3 columns]

# %%
newdf.isnull()
# Out:
#          B      C      E
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 5    False  False  False
# 6    False  False  False
# ..     ...    ...    ...
# 295  False  False  False
# 296  False  False  False
# 297  False  False  False
# 298  False  False  False
# 299  False  False  False
#
# [298 rows x 3 columns]

# %%
newdf['C'].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 5      False
# 6      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: C, Length: 298, dtype: bool

# %%
newdf.loc[:,['C']] = 46

# %%
newdf
# Out:
#                B   C         E
# 1       0.040576  46  0.438977
# 2    8954.455000  46  0.359321
# 3       0.765488  46  0.576856
# 5       0.481383  46  0.745009
# 6       0.934376  46  0.510244
# ..           ...  ..       ...
# 295     0.803945  46  0.279954
# 296     0.757105  46  0.908310
# 297     0.691470  46  0.364735
# 298     0.545394  46  0.687652
# 299     0.966316  46  0.579266
#
# [298 rows x 3 columns]

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25
# 2  Alfred  NaN        NaT

# %%
df1.dropna(how = 'all', axis=1)
# Out:
#      name       born
# 0  Alfred        NaT
# 1  Batman 1940-04-25
# 2  Alfred        NaT

# %%
df1.drop_duplicates(subset=['name'], keep  = False)
# Out:
#      name  toy       born
# 1  Batman  NaN 1940-04-25

# %%
newdf.shape
# Out:
# (298, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, one to seven
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   City    7 non-null      object
#  2   Marks   7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 524.0+ bytes

# %%
df
# Out:
#            Name       City  Marks
# one         Ram  Bnagalore     85
# two       Rohan     Jaipur     60
# three     Kirti      Delhi     78
# four   Himanshi    Gurgaon     54
# five     Chahat     Ambala     89
# six      Charan    Lucknow     91
# seven     Akash  Hyderabad     68

# %%
df.value_counts(dropna = False)
# Out:
# Name      City       Marks
# Akash     Hyderabad  68       1
# Chahat    Ambala     89       1
# Charan    Lucknow    91       1
# Himanshi  Gurgaon    54       1
# Kirti     Delhi      78       1
# Ram       Bnagalore  85       1
# Rohan     Jaipur     60       1
# dtype: int64

# %%
df['Marks'].value_counts(dropna = True)
# Out:
# 85    1
# 60    1
# 78    1
# 54    1
# 89    1
# 91    1
# 68    1
# Name: Marks, dtype: int64

# %%
df1.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df1.isnull()
# Out:
#     name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
df
# Out:
#            Name       City  Marks
# one         Ram  Bnagalore     85
# two       Rohan     Jaipur     60
# three     Kirti      Delhi     78
# four   Himanshi    Gurgaon     54
# five     Chahat     Ambala     89
# six      Charan    Lucknow     91
# seven     Akash  Hyderabad     68

# %%
dict = {
    "Empno" : [1001,1002,1003],
    "Salary" : [40000,30000,70000]
}

# %%
df2 = pd.DataFrame(dict)

# %%
df2
# Out:
#    Empno  Salary
# 0   1001   40000
# 1   1002   30000
# 2   1003   70000

# %%
df2.describe()
# Out:
#         Empno        Salary
# count     3.0      3.000000
# mean   1002.0  46666.666667
# std       1.0  20816.659995
# min    1001.0  30000.000000
# 25%    1001.5  35000.000000
# 50%    1002.0  40000.000000
# 75%    1002.5  55000.000000
# max    1003.0  70000.000000

# %%
df2.mean()
# Out:
# Empno      1002.000000
# Salary    46666.666667
# dtype: float64

# %%
df2.corr()
# Out:
#            Empno    Salary
# Empno   1.000000  0.720577
# Salary  0.720577  1.000000

# %%
df.count()
# Out:
# Name     7
# City     7
# Marks    7
# dtype: int64

# %%
df2.count()
# Out:
# Empno     3
# Salary    3
# dtype: int64

# %%
df2.max()
# Out:
# Empno      1003
# Salary    70000
# dtype: int64

# %%
df2.min()
# Out:
# Empno      1001
# Salary    30000
# dtype: int64

# %%
df2.median()
# Out:
# Empno      1002.0
# Salary    40000.0
# dtype: float64

# %%
df2.std()
# Out:
# Empno         1.000000
# Salary    20816.659995
# dtype: float64
